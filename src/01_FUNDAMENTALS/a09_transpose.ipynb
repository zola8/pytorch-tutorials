# %%
import torch

t1 = torch.tensor([[1, 2], [3, 4], [5, 6]])
t2 = torch.tensor([[1, 2], [3, 4], [5, 6]])

# torch.matmul(t1, t2)
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (3x2 and 3x2)

# %% [markdown]
# To fix shape issues, we can manipulate the shape of one of our tensors using transpose.
#
# The **transpose** switches the axes or dimension of a given tensor.

# %%
t1
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
t1.T
# Out:
# tensor([[1, 3, 5],
#         [2, 4, 6]])
